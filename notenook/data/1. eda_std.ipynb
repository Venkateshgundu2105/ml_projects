# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Check Missing values
#
# Check Duplicates
#
# Check data type
#
# Check the number of unique values of each column
#
# Check statistics of data set
#
# Check various categories present in the different categorical column

# %%
df.shape
# Out:
# (1000, 8)

# %%
#Check Missing values

df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#Check Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Check data type


df.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# parental_level_of_education    object
# lunch                          object
# test_preparation_course        object
# math_score                      int64
# reading_score                   int64
# writing_score                   int64
# dtype: object

# %%
#Check data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#Check data type
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
## adding columns like TOTAL_SCOR, AVG_SCORE
df['total_score']= df['math_score']+df["reading_score"]+df["writing_score"]

# %%
df.drop("avg-score", axis=1, inplace=True)
df['avg_score']= df['total_score']/3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.drop("avg-score", axis=1, inplace=True)
#       2 df['avg_score']= df['total_score']/3
#
# File e:\Projects\ml_projects\.venv\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  avg_score
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# we can see how many students got full marks

# %%
df[df['avg_score']==100]
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      total_score  avg_score
# 458          300      100.0
# 916          300      100.0
# 962          300      100.0

# %% [markdown]
# we can see how many students got less than 30 avg_mark

# %%
df[df['avg_score']<=30].sort_values(by= 'avg_score', ascending=False)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 211    male        group C                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 601  female        group C                 high school      standard
# 17   female        group B            some high school  free/reduced
# 76     male        group E            some high school      standard
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 211                    none          35             28             27
# ...

# %% [markdown]
# sutdents who got absent in atleaast one exam

# %%
df[(df['writing_score']==0) | (df['reading_score']==0) | (df['math_score']==0) ]
# Out:
#     gender race_ethnicity parental_level_of_education         lunch  \
# 59  female        group C            some high school  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score  \
# 59                    none           0             17             10
#
#     total_score  avg_score
# 59           27        9.0

# %% [markdown]
# ### Data Visualisation

# %%
sns.histplot(data=df,x=df['total_score'],hue='gender', kde=True)
plt.show()

# %% [markdown]
# by the above plot we can observe the female students performs better than male sthudents

# %%
sns.histplot(data=df,x=df['total_score'],hue='lunch', kde=True)
plt.show()

# %% [markdown]
# we can say.. students who taking standrd lunch are performing well

# %%
sns.histplot(data=df,x=df['total_score'],hue='race_ethnicity', kde=True)
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math_score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading_score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing_score',data=df,color='blue',linewidth=3)
plt.show()

# %% [markdown]
# From the above three plots its clearly visible that most of the students score in between 60-80 in Maths whereas in reading and writing most of them score from 50-80

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race_Ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental_Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# Number of Male and Female students is almost equal
#
# Number students are greatest in Group C
#
# Number of students who have standard lunch are greater
#
# Number of students who have not enrolled in any test preparation course is greater
#
# Number of students whose parental education is "Some College" is greater followed closely by "Associate's Degree"

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    total_score  avg_score
# 0          218  72.666667
# 1          247  82.333333

# %%
plt.subplot(1, 3, 1)
sns.histplot(data=df,x=df['math_score'], hue=df['gender'])
plt.title('math_score')

plt.subplot(1,3,2)
sns.histplot(data=df,x=df['reading_score'], hue=df['gender'])
plt.title('reading_score')

plt.subplot(1,3,3)
sns.histplot(data=df,x=df['writing_score'], hue=df['gender'])
plt.title('writing_score')
# Out:
# Text(0.5, 1.0, 'writing_score')
